# %%
#write a program to accept name, all marks - 6 subjects.Print average percentage, total marks?

name = input("Enter the  Name: ")
print("Enter the Student 6 Subject Marks")
s1= int(input("Enter the marks obtained for English: "))
s2= int(input("Enter the marks obtained for Maths: "))
s3= int(input("Enter the marks obtained for Telugu: "))
s4= int(input("Enter the marks obtained for Science: "))
s5= int(input("Enter the marks obtained for EVS: "))
s6= int(input("Enter the marks obtained for History: "))

total = s1+s2+s3+s4+s5+s6
average = round(total/6,2)
percentage = (total/600)*100


print("Total Marks obtained",total)
print("Student Average",average)
print("Student Percentage",percentage)
# Out:
# Enter the  Name: Dave
# Enter the Student 6 Subject Marks
# Enter the marks obtained for English: 75
# Enter the marks obtained for Maths: 62
# Enter the marks obtained for Telugu: 55
# Enter the marks obtained for Science: 88
# Enter the marks obtained for EVS: 90
# Enter the marks obtained for History: 74
# Total Marks obtained 444
# Student Average 74.0
# Student Percentage 74.0
