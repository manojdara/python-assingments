# %%
s = "Monty Python's Flying Circus"

print("The value of the variable is: ",s)
print("Length of the string: ",len(s))
print(s[:])
print(s[::])
print(s[0:len(s):1])
print(s[1:])
print(s[-1:])
print(s[1:-1])
print(s[-1])
print(s[::-1])
print(s[::-2])
print(s[::1])
print(s[::2])
print(s[::3])
print(s[:1])
print(s[:-3])
print(s[-3::-1])
print(s[-3::1])
print(s[13::1])
print(s[1:1:1])
print(s[1::1])
print(s[-1::-1])
print(s[3:-27])
print(s[4:-17])
print(s[-21:-11])
print(s[-21:11])
print(s[21:11])
print(s[21:-11])
print(s[13::-1])
print(s[13::1])
print(s[:15:-1])
# Out:
# The value of the variable is:  Monty Python's Flying Circus
# Length of the string:  28
# Monty Python's Flying Circus
# Monty Python's Flying Circus
# Monty Python's Flying Circus
# onty Python's Flying Circus
# s
# onty Python's Flying Circu
# s
# sucriC gniylF s'nohtyP ytnoM
# sci nyFsnhy to
# Monty Python's Flying Circus
# MnyPto' ligCru
# MtPh'Fi rs
# M
# Monty Python's Flying Cir
# criC gniylF s'nohtyP ytnoM
# cus
# s Flying Circus
#
# onty Python's Flying Circus
# sucriC gniylF s'nohtyP ytnoM
#
# y Pytho
# ython's Fl
# ytho
#
#
# s'nohtyP ytnoM
# s Flying Circus
# sucriC gniyl

# %%
print(s[:15:1])
print(s[21:-11:-1])
print(s[13:-13:-1])
print(s[5:-8:1])
print(s[5:-8:-1])
print(s[5:8:1])
print(s[5:8:-1])
print(s[-5:-8:1])
print(s[-5:-8:-1])
print(s[-5:8:1])
print(s[8:-5:2])
print(s[-8:-5:2])
print(s[-8:-5:-2])
print(s[-8:5:2])
print(s[-8:5:-2])
print(s[8:-5:2])
print(s[8:-5:-2])
print(s[30:])
print(s[30]) #The string has 28 characters due to which we get string index out of rangeb
# Out:
# Monty Python's
#  gni
#
#  Python's Flyin
#
#  Py
#
#
# iC
#
# to' ligC
# gC
#
#
# gil 'otP
# to' ligC
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 19
#      17 print(s[8:-5:-2])
#      18 print(s[30:])
# ---> 19 print(s[30])
#
# IndexError: string index out of range

# %%
# Print the below words using slicing and concatenation
s = "Monty Python's Flying Circus"

# 1. Moon
print(s[:2]+s[10:12])
# 2. Crying
print(s[-6:-2:2]+s[-11:-7:1])
# 3. MontyPython'sFlyingCircus
print(s[:5]+s[6:14:1]+s[15:21]+s[22:])
# Out:
# Moon
# Crying
# MontyPython'sFlyingCircus

# %% [markdown]
# # Go Through Python List Methods
#
# | Method | Description |
# |----------|-------------|
# | `append()` | Adds an element at the end of the list |
# | `clear()` | Removes all the elements from the list |
# | `copy()` | Returns a copy of the list |
# | `count()` | Returns the number of elements with the specified value |
# | `extend()` | Adds the elements of a list (or any iterable) to the end of the current list |
# | `index()` | Returns the index of the first element with the specified value |
# | `insert()` | Adds an element at the specified position |
# | `pop()` | Removes the element at the specified position |
# | `remove()` | Removes the item with the specified value |
# | `reverse()` | Reverses the order of the list |
# | `sort()` | Sorts the list |

# %% [markdown]
# # Python String Methods
#
# | Method | Description |
# |----------|-------------|
# | `capitalize()` | Converts the first character to upper case |
# | `casefold()` | Converts string into lower case |
# | `center()` | Returns a centered string |
# | `count()` | Returns the number of times a specified value occurs in a string |
# | `encode()` | Returns an encoded version of the string |
# | `endswith()` | Returns True if the string ends with the specified value |
# | `expandtabs()` | Sets the tab size of the string |
# | `find()` | Searches the string for a specified value and returns its position |
# | `format()` | Formats specified values in a string |
# | `format_map()` | Formats specified values from a dictionary in a string |
# | `index()` | Searches the string for a specified value and returns its position |
# | `isalnum()` | Returns True if all characters are alphanumeric |
# | `isalpha()` | Returns True if all characters are in the alphabet |
# | `isascii()` | Returns True if all characters are ASCII characters |
# | `isdecimal()` | Returns True if all characters are decimals |
# | `isdigit()` | Returns True if all characters are digits |
# | `isidentifier()` | Returns True if the string is a valid identifier |
# | `islower()` | Returns True if all characters are lower case |
# | `isnumeric()` | Returns True if all characters are numeric |
# | `isprintable()` | Returns True if all characters are printable |
# | `isspace()` | Returns True if all characters are whitespaces |
# | `istitle()` | Returns True if the string follows title case rules |
# | `isupper()` | Returns True if all characters are upper case |
# | `join()` | Joins elements of an iterable into a string |
# | `ljust()` | Returns a left-justified version of the string |
# | `lower()` | Converts a string into lower case |
# | `lstrip()` | Returns a left trim version of the string |
# | `maketrans()` | Returns a translation table for use in `translate()` |
# | `partition()` | Splits the string into three parts |
# | `replace()` | Replaces a specified value with another value |
# | `rfind()` | Returns the highest index of a substring |
# | `rindex()` | Returns the highest index of a substring |
# | `rjust()` | Returns a right-justified version of the string |
# | `rpartition()` | Splits the string into three parts from the right |
# | `rsplit()` | Splits the string from the right and returns a list |
# | `rstrip()` | Removes trailing spaces (or specified characters) |
# | `split()` | Splits the string into a list |
# | `splitlines()` | Splits the string at line breaks |
# | `startswith()` | Returns True if the string starts with the specified value |
# | `strip()` | Removes leading and trailing whitespace |
# | `swapcase()` | Swaps lowercase to uppercase and vice versa |
# | `title()` | Converts first letter of each word to uppercase |
# | `translate()` | Returns a translated string using a translation table |
# | `upper()` | Converts a string into upper case |
# | `zfill()` | Pads the string with leading zeros |

# %%
txt = "python is FUN!"

x = txt.capitalize()

print (x)
# Out:
# Python is fun!

# %%
txt = "Hello, And Welcome To My World!"

x = txt.casefold()

print(x)
# Out:
# hello, and welcome to my world!

# %%
txt = "banana"

x = txt.center(20)

print(x)
# Out:
#        banana

# %%
txt = "I love apples, apple are my favorite fruit"

x = txt.count("apple")

print(x)
# Out:
# 2

# %%
# Default Encoding is UTF-8
txt = "My name is Ståle"

x = txt.encode()

print(x)
# Out:
# b'My name is St\xc3\xa5le'

# %%
txt = "Hello, welcome to my world."

x = txt.endswith(".")

print(x)
# Out:
# True

# %%
# This method sets the tab size to the specified number of whitespaces. Default tabsize is 8
txt = "H\te\tl\tl\to"

x =  txt.expandtabs(2)

print(x)
# Out:
# H e l l o

# %%
txt = "Hello, welcome to my world."

x = txt.find("welcome")

print(x)
print(txt.find("q"))
print(txt.index("q"))
# Out:
# 7
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 7
#       5 print(x)
#       6 print(txt.find("q"))
# ----> 7 print(txt.index("q"))
#
# ValueError: substring not found

# %%
txt = "For only {price:.2f} dollars!"
print(txt.format(price = 49))
# Out:
# For only 49.00 dollars!

# %%
txt = "     banana     "

x = txt.strip()

print("of all fruits", x, "is my favorite")
# Out:
# of all fruits banana is my favorite
