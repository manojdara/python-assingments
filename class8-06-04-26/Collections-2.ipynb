# %% [markdown]
# # 1. How memory is managed in python ?
#
# Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager. The Python memory manager has different components which deal with various dynamic storage management aspects, like sharing, segmentation, preallocation or caching.
#
# Python manages memory automatically, it does required to allocate or free memory by anyone. During the creation of an object (such as a list, dictionary, or string), it is stored in heap memory, and variables hold references to that object. Python keeps track of how many references point to each object using reference counting. When an object is no longer referenced, Python automatically removes it from memory. Python stores all objects in a private heap — a memory pool managed entirely by the Python interpreter. Overall, Python's memory management is automatic.

# %%
# 2. Update the Student Marks Dashboard with collections ?

student = {
    "name": "David",
    "marks": [70,80,90,60,75,85]
}

# calculate the total

total_marks = sum(student["marks"])

# Calculate Average 

average = total_marks/len(student["marks"])


# Percentage 

percent = (total_marks/(600))*100

print("STUDENT DASHBOARD")
print("===================")
print("Student Name: ",student["name"])
print("Student Subject Marks: ",student["marks"])
print("Student Total Marks: ",total_marks)
print("Student Average: ",round(average,2))
print("Student Percentage: ", round(percent,2),"%")
# Out:
# STUDENT DASHBOARD
# ...
# Student Name:  David
# Student Subject Marks:  [70, 80, 90, 60, 75, 85]
# Student Total Marks:  460
# Student Average:  76.67
# Student Percentage:  76.67 %

# %% [markdown]
# # 3. How agent is comparable with programming ?
#
# Programming is used to implement specific business logic and predefined rules that are executed exactly as coded. The behavior of the program is determined by the instructions written by the developer.
#
# An AI agent, on the other hand, has a broader scope. It analyzes the available information, evaluates the context, makes decisions, and determines the next steps required to achieve a given objective. Rather than following only fixed rules, it can adapt its actions based on the situation and the goal it is trying to accomplish.
