# %%
#Create an integer variable and print it.
i = 5
print(i)
print (type(i))
# Out:
# 5
# <class 'int'>

# %%
#Create a float variable and print it.
f = 6.0
print(f)
print (type(f))
# Out:
# 6.0
# <class 'float'>

# %%
#Create a string variable with your name and print it.
name = "Manoj"
print(name)
# Out:
# Manoj

# %%
#Take the user’s age as input and print it.
age = int(input("Please enter your age: "))
print("I am {} year's old".format(age))
# Out:
# Please enter your age: 20
# I am 20 year's old

# %%
#Take the user’s height as input using float and print it.

height = float(input("Please enter your height in Centimeters: "))
print("My height is {} centimeters".format(height))
# Out:
# Please enter your height in Centimeters: 160
# My height is 160.0 centimeters

# %%
#Ask the user for their favourite movie and print it.
movie = input("What is your favourite movie: ")
print(movie)
# Out:
# What is your favourite movie: cars
# cars

# %%
#Take two integer inputs and print their sum.
print("Addition of 2 Numbers will begin",flush=True)
n1 = int(input("Enter your 1st Number"))
n2 = int(input("Enter your 2nd Number"))
add = (n1 + n2)
print("The Addition of two numbers: ",add)
# Out:
# Addition of 2 Numbers will begin
# Enter your 1st Number10
# Enter your 2nd Number20
# The Addition of two numbers:  30

# %%
#Take one integer and one float input and print both values.

num1 = int(input("Enter an Integer Number "))
num2 = float(input("Enter a Float Number "))
print("The Integer number is {} and Float number is {}".format(num1,num2))
# Out:
# Enter an Integer Number 10
# Enter a Float Number 3.0
# The Integer number is 10 and Float number is 3.0

# %%
#Ask the user for their name and age, then print:#“My name is ___ and I am ___ years old.”
name = input("Enter your name ")
age = int(input("Enter your age "))
print("My name is {} and I am {} years old.".format(name,age))
# Out:
# Enter your name Dave
# Enter your age 18
# My name is Dave and I am 18 years old.

# %%
#Create variables for:
#name (string)
#age (int)
#marks (float)
#Print all values in a single output statement.

name = input("Enter your name ")
age = int(input("Enter your age "))
marks = float(input("Enter your marks "))
print("The name is {} age is {} and marks obtained {} ".format(name,age,marks))
# Out:
# Enter your name Kevin
# Enter your age 20
# Enter your marks 80
# The name is Kevin age is 20 and marks obtained 80.0
